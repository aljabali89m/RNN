# %% [markdown]
# #Mohammad Aljabali
# ## Moneeb Abu Jamoos

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Recurrent Neural Network (RNN)

# %% [markdown]
# ## Data Preprocessing

# %%
dataset_train = pd.read_csv('/content/Google_Stock_Price_Train.csv')
dataset_train.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
train = dataset_train.loc[:, ["Open"]].values
train
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
train_scaled = scaler.fit_transform(train)
train_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
plt.plot(train_scaled)
plt.show()

# %%
print(len(train_scaled))
print(train_scaled.shape)
# Out:
# 1258
# (1258, 1)

# %%
# Creating a data structure with 50 timesteps and 1 output
X_train = []
y_train = []
timesteps = 50
for i in range(timesteps, 1258):
    X_train.append(train_scaled[i-timesteps:i, 0])
    y_train.append(train_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train
# Out:
# array([[[0.08581368],
#         [0.09701243],
#         [0.09433366],
#         ...,
#         [0.03675869],
#         [0.04486941],
#         [0.05065481]],
#
#        [[0.09701243],
#         [0.09433366],
#         [0.09156187],
#         ...,
#         [0.04486941],
#         [0.05065481],
#         [0.05214302]],
#
#        [[0.09433366],
#         [0.09156187],
#         [0.07984225],
#         ...,
#         [0.05065481],
#         [0.05214302],
#         [0.05612397]],
#
#        ...,
#
#        [[0.9313937 ],
#         [0.94636878],
#         [0.96569685],
#         ...,
#         [0.95475854],
#         [0.95204256],
#         [0.95163331]],
#
#        [[0.94636878],
#         [0.96569685],
#         [0.97510976],
#         ...,
#         [0.95204256],
#         [0.95163331],
#         [0.95725128]],
#
#        [[0.96569685],
#         [0.97510976],
#         [0.95966962],
#         ...,
#         [0.95163331],
#         [0.95725128],
#         [0.93796041]]])

# %%
y_train
# Out:
# array([0.05214302, 0.05612397, 0.05818885, ..., 0.95725128, 0.93796041,
#        0.93688146])

# %% [markdown]
# ## RNN model

# %%
# Import libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# Initializing the RNN
model = Sequential()

# Adding the first RNN layer and some Dropout regularisation
model.add(SimpleRNN(units = 50,activation='tanh', return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))

# Adding a second RNN layer and some Dropout regularisation
model.add(SimpleRNN(units = 50,activation='tanh', return_sequences = True))
model.add(Dropout(0.2))

# Adding a third RNN layer and some Dropout regularisation
model.add(SimpleRNN(units = 50,activation='tanh', return_sequences = True))
model.add(Dropout(0.2))

# Adding a fourth RNN layer and some Dropout regularisation
model.add(SimpleRNN(units = 50))
model.add(Dropout(0.2)) # Avoid overfitting

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 128ms/step - loss: 0.5962
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3053
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1980
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1633
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1328
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1045
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0858
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0740
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0641
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0512
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0453
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0426
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0384
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0360
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0313
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0256
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0247
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0221
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0213
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0201
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0178
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0158
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0150
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0150
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0137
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0139
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0131
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0118
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0117
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0097
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0102
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0088
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0098
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0090
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0078
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0083
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0074
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0070
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0079
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0068
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0055
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0054
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0057
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0062
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0056
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0055
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0054
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0053
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0046
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0046
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0045
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0048
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0039
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0039
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0049
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0038
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0036
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0040
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0041
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0036
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0036
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0038
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0032
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0034
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0032
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0027
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0027
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0029
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 85/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 86/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023
# Epoch 87/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 88/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 89/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024
# Epoch 90/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023
# Epoch 91/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022
# Epoch 92/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 93/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0026
# Epoch 94/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0024
# Epoch 95/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023
# Epoch 96/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0028
# Epoch 97/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022
# Epoch 98/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 99/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0023
# Epoch 100/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020

# %% [markdown]
# ## Prediction the test model

# %%
# Getting the real stock price of 2017
dataset_test = pd.read_csv('/content/Google_Stock_Price_Train.csv')
dataset_test.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
real_stock_price = dataset_test.loc[:, ["Open"]].values
real_stock_price
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
# Getting the prediction of stock price of 2017
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
dataset_total
# Out:
# 0       325.25
# 1       331.27
# 2       329.83
# 3       328.34
# 4       322.04
#          ...
# 1253    790.90
# 1254    790.68
# 1255    793.70
# 1256    783.33
# 1257    782.75
# Name: Open, Length: 2516, dtype: float64

# %%
inputs = dataset_total[len(dataset_total) - len(dataset_test) - timesteps:].values.reshape(-1,1) # Reshapes the 1D Numpy array into a 2D array
inputs = scaler.transform(inputs)  # min max scaler
inputs
# Out:
# array([[0.97510976],
#        [0.95966962],
#        [0.97808617],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %% [markdown]
# ## Visualization

# %%
X_test = []
for i in range(timesteps, 70):
  X_test.append(inputs[i - timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

# Visualizing Results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step

# %% [markdown]
# # Long Short-Term Memory (LSTM)

# %%
data_train = pd.read_csv('/content/Google_Stock_Price_Train.csv')
data_test = pd.read_csv('/content/Google_Stock_Price_Test.csv')

# %% [markdown]
# ## Data Preprocessing

# %%
train_set = data_train.loc[:, ["Open"]].values
train_set
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
# Feature Scaling
minmax_scale = MinMaxScaler(feature_range=(0,1))
train_set_scaled = minmax_scale.fit_transform(train_set)
train_set_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
# Create sequences with lockback windown
X_train = []
y_train = []
timesteps = 50

for i in range(timesteps, 1258):
    X_train.append(train_set_scaled[i-timesteps:i, 0])
    y_train.append(train_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshape to 3D: (samples, timesteps, features)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train
# Out:
# array([[[0.08581368],
#         [0.09701243],
#         [0.09433366],
#         ...,
#         [0.03675869],
#         [0.04486941],
#         [0.05065481]],
#
#        [[0.09701243],
#         [0.09433366],
#         [0.09156187],
#         ...,
#         [0.04486941],
#         [0.05065481],
#         [0.05214302]],
#
#        [[0.09433366],
#         [0.09156187],
#         [0.07984225],
#         ...,
#         [0.05065481],
#         [0.05214302],
#         [0.05612397]],
#
#        ...,
#
#        [[0.9313937 ],
#         [0.94636878],
#         [0.96569685],
#         ...,
#         [0.95475854],
#         [0.95204256],
#         [0.95163331]],
#
#        [[0.94636878],
#         [0.96569685],
#         [0.97510976],
#         ...,
#         [0.95204256],
#         [0.95163331],
#         [0.95725128]],
#
#        [[0.96569685],
#         [0.97510976],
#         [0.95966962],
#         ...,
#         [0.95163331],
#         [0.95725128],
#         [0.93796041]]])

# %% [markdown]
# ## LSTM Model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
# Let's create a dummy model_lstm to make predictions
model_lstm = Sequential()
model_lstm.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units=50, return_sequences=False))
model_lstm.add(Dropout(0.2))
model_lstm.add(Dense(units=1))

# Compile the model_lstm
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Train model_lstm
print("Training the model_lstm...")
history = model_lstm.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Training the model_lstm...
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - loss: 0.0607 - val_loss: 0.0015
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 9.3824e-04
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 9.4599e-04
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 9.6374e-04
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 9.1842e-04
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 8.7270e-04
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 8.5442e-04
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 8.3489e-04
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 8.4934e-04
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 8.2861e-04
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 8.8835e-04
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 7.5947e-04
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - val_loss: 8.0873e-04
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - val_loss: 8.6421e-04
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.3512e-04
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 7.2601e-04
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 7.9558e-04
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 7.2541e-04
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 8.8125e-04
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 7.9638e-04
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 6.9184e-04
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 7.8312e-04
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 7.2155e-04
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 7.2026e-04
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 7.1168e-04
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4023e-04 - val_loss: 0.0012
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 7.4958e-04
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.7986e-04 - val_loss: 8.3333e-04
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.9797e-04 - val_loss: 6.4282e-04
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.8743e-04 - val_loss: 0.0014
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 7.6439e-04
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 6.1643e-04
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.7293e-04 - val_loss: 6.2320e-04
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - val_loss: 6.9658e-04
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 7.4377e-04
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010 - val_loss: 7.2470e-04
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.8955e-04 - val_loss: 6.1071e-04
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0355e-04 - val_loss: 5.8951e-04
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6232e-04 - val_loss: 0.0010
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 7.3746e-04
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2248e-04 - val_loss: 6.5766e-04
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6338e-04 - val_loss: 5.8319e-04
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - val_loss: 5.9165e-04
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0342e-04 - val_loss: 9.8416e-04
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2856e-04 - val_loss: 8.7948e-04

# %%
# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Prediction the test model

# %%
# Getting the real stock price of 2017
dataset_test = pd.read_csv('/content/Google_Stock_Price_Test.csv')
dataset_test.head()
# Out:
#        Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3  1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4  1/9/2017  806.40  809.97  802.83  806.65  1,272,400

# %%
real_stock_price = dataset_test.loc[:, ["Open"]].values
real_stock_price
# Out:
# array([[778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
# Getting the predidtion of stock in 2017
dataset_total = pd.concat((data_train['Open'], data_test['Open']), axis = 0)
dataset_total
# Out:
# 0     325.25
# 1     331.27
# 2     329.83
# 3     328.34
# 4     322.04
#        ...
# 15    829.62
# 16    837.81
# 17    834.71
# 18    814.66
# 19    796.86
# Name: Open, Length: 1278, dtype: float64

# %%
inputs_lstm = dataset_total[len(dataset_total) - len(dataset_test) - timesteps:].values.reshape(-1,1) # Reshapes the 1D Numpy array into a 2D array
inputs_lstm = scaler.transform(inputs_lstm)  # min max scaler
inputs_lstm
# Out:
# array([[0.97510976],
#        [0.95966962],
#        [0.97808617],
#        [1.        ],
#        [0.98076494],
#        [0.97083116],
#        [0.98450406],
#        [0.96054394],
#        [0.9371419 ],
#        [0.92841729],
#        [0.90804747],
#        [0.8771858 ],
#        [0.92153434],
#        [0.93809063],
#        [0.93165414],
#        [0.95254483],
#        [0.88812412],
#        [0.88637547],
#        [0.87032145],
#        [0.88563137],
#        [0.90743359],
#        [0.91571173],
#        [0.89941588],
#        [0.91805566],
#        [0.9089404 ],
#        [0.9024853 ],
#        [0.89456061],
#        [0.91600938],
#        [0.9132934 ],
#        [0.88979835],
#        [0.86589404],
#        [0.89030062],
#        [0.90335962],
#        [0.89642086],
#        [0.91777662],
#        [0.93176576],
#        [0.94114145],
#        [0.95762334],
#        [0.96413424],
#        [0.96402262],
#        [0.96971501],
#        [0.95077759],
#        [0.96294367],
#        [0.96123223],
#        [0.95475854],
#        [0.95204256],
#        [0.95163331],
#        [0.95725128],
#        [0.93796041],
#        [0.93688146],
#        [0.92955205],
#        [0.94731751],
#        [0.94307612],
#        [0.96015329],
#        [0.98087655],
#        [0.98359253],
#        [0.97827219],
#        [0.98225314],
#        [0.98288563],
#        [0.98214153],
#        [0.979779  ],
#        [0.97849542],
#        [0.98182528],
#        [0.98245777],
#        [1.01045465],
#        [1.02407173],
#        [1.03930724],
#        [1.03354044],
#        [0.99624228],
#        [0.9631297 ]])

# %%
X_test = []
for i in range(timesteps, len(inputs_lstm)):
  X_test.append(inputs_lstm[i - timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Making predictions
predicted_stock_price = model_lstm.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step

# %%
# Visualizing Results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # Ploty with Zoom In/Out

# %%
# !pip -q install plotly ipywidgets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.9 MB/s eta 0:00:00

# %%
from google.colab import output
output.enable_custom_widget_manager() # This enable will make ipywidgets work nicely
import plotly.graph_objects as go
import ipywidgets as widgets

# %%
# Ensure proper dtypes and tidy ordering
data_train["Date"] = pd.to_datetime(data_train["Date"], errors="coerce")
data_train["Open"] = pd.to_numeric(data_train["Open"], errors="coerce")

# Drop bad rows, sort, reset index
data_train = data_train.dropna(subset=["Date", "Open"]).sort_values("Date").reset_index(drop=True)

# Optional: ensure business-day cadence and fill gaps (safer for markets)
bidx = pd.date_range(data_train["Date"].min(), data_train["Date"].max(), freq="B")
data_train = (data_train
              .set_index("Date")
              .reindex(bidx))
data_train["Open"] = data_train["Open"].ffill().bfill()
data_train = data_train.rename_axis("Date").reset_index()

# Final sanity check
assert data_train["Date"].notna().all() and data_train["Open"].notna().all()
print("✅ Data ready. Rows:", len(data_train))
# Out:
# ✅ Data ready. Rows: 1304

# %%
try:
    scaler_y  # if you created it during training
except NameError:
    from sklearn.preprocessing import MinMaxScaler
    scaler_y = MinMaxScaler().fit(data_train["Open"].values.reshape(-1,1))

# %% [markdown]
# ## Choose model

# %%
model = model_lstm # should display a Keras model summary repr

lookback = model.input_shape[1]
n_features = model.input_shape[2]
assert n_features == 1, "This block assumes a univariate model (only 'Open'). If multivariate, see notes below."
print("lookback:", lookback, "  n_features:", n_features)
# Out:
# lookback: 50   n_features: 1

# %%
def _last_lookback_window_univariate(series: pd.Series):
    """Scale 'Open' and return last (1, lookback, 1) window."""
    scaled = scaler_y.transform(series.values.reshape(-1,1))
    return scaled[-lookback:].reshape(1, lookback, 1)

def forecast_next_open(n_days: int) -> pd.DataFrame:
    """
    Iterative one-step-ahead forecast of Open for next n_days (business days).
    Returns DataFrame with Date, Predicted (in original price units).
    """
    # Future dates (business days)
    # Take the last days
    # Create future business days (except weekend)
    last_date = data_train["Date"].max()
    future_dates = pd.date_range(last_date + pd.Timedelta(days=1), periods=n_days, freq="B")

    # Seed window from the last lookback Open prices
    window = _last_lookback_window_univariate(data_train["Open"])

    preds_scaled = []
    for _ in range(n_days):
      # Predict the next days with the scaled of Open Price (1, 1)
        yhat_scaled = model.predict(window, verbose=0)  # (1,1)
        preds_scaled.append(yhat_scaled[0,0])
        # roll window forward and append the new prediction
        window = np.concatenate([window[:,1:,:], yhat_scaled.reshape(1,1,1)], axis=1)
    # Scaled all the prediction into [0, 1] shapes
    # use inverse_transform to map them back to the Original Price Sale
    preds = scaler_y.inverse_transform(np.array(preds_scaled).reshape(-1,1)).ravel()
    return pd.DataFrame({"Date": future_dates, "Predicted": preds})

# %% [markdown]
# ## Ploty with Silder

# %%
slider = widgets.IntSlider(value=7, min=1, max=30, step=1, description="Days:")
output_box = widgets.Output()

def plot_open_with_slider(n_days: int):
    with output_box:
        output_box.clear_output(wait=True)
        fut = forecast_next_open(n_days)

        fig = go.Figure()
        # history (Open)
        fig.add_trace(go.Scatter(
            x=data_train["Date"], y=data_train["Open"],
            name="History (Open)", mode="lines"))

        # forecast line
        fig.add_trace(go.Scatter(
            x=fut["Date"], y=fut["Predicted"],
            name=f"Forecast +{n_days}d", mode="lines+markers"))

        # Vertical boundary as shape (avoids datetime annotation bugs)
        cutoff_dt = pd.to_datetime(data_train["Date"].max()).to_pydatetime()
        fig.add_shape(type="line", x0=cutoff_dt, x1=cutoff_dt, y0=0, y1=1,
                      xref="x", yref="paper", line=dict(dash="dot"))
        fig.add_annotation(x=cutoff_dt, y=1, xref="x", yref="paper",
                           text="Forecast start", showarrow=False, yshift=10)

        fig.update_layout(
            title=f"Open price forecast: next {n_days} business days",
            xaxis_title="Date", yaxis_title="Open Price",
            legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
            margin=dict(l=0, r=0, t=60, b=0),
        )
        fig.update_xaxes(type="date")
        fig.show()

widgets.interact(plot_open_with_slider, n_days=slider)
display(output_box)
# Out:
# interactive(children=(IntSlider(value=7, description='Days:', max=30, min=1), Output()), _dom_classes=('widget…
# Output()

# %% [markdown]
# # Monte Carlo Dropout

# %% [markdown]
# ## CI (confidence interval): uncertainty of the mean line itself. Narrower.
#
# ##  PI (prediction interval): uncertainty of the actual future value (mean + randomness/volatility). Wider. => Recommended in Stock

# %%
# Confidence Interval ( CI )
# Prediction Interval ( PI )
def forecast_open_mc_dropout(n_days: int, T: int = 100, conf: float = 0.95):
    """
    Monte Carlo Dropout iterative forecast.
    Returns DataFrame with Date, Mean, CI_Lower, CI_Upper, PI_Lower, PI_Upper.
    """
    # future dates
    last_date = data_train["Date"].max()
    future_dates = pd.date_range(last_date + pd.Timedelta(days=1), periods=n_days, freq="B")

    # seed window
    def seed():
        scaled = scaler_y.transform(data_train["Open"].values.reshape(-1,1))
        return scaled[-lookback:].reshape(1, lookback, 1)

    # T stochastic path (Dropout activate)
    paths_scaled = []
    for _ in range(T):
        w = seed()
        seq = []
        for _ in range(n_days):
            # IMPORTANT: call the model with training=True to keep dropout on
            yhat_scaled = model(w, training=True).numpy()   # shape (1,1)
            seq.append(yhat_scaled[0,0])
            w = np.concatenate([w[:,1:,:], yhat_scaled.reshape(1,1,1)], axis=1)
        paths_scaled.append(seq)

    paths_scaled = np.array(paths_scaled)           # (T, n_days)
    # inverse transform each path to price units
    paths = scaler_y.inverse_transform(paths_scaled.reshape(-1,1)).reshape(T, n_days)

    # Statistics per horizon
    mean = paths.mean(axis=0)
    std = paths.std(axis=0)

    # 95% CI for the mean prediction at each horizon
    z = 1.96 # for 95% of data lies with +-1.96 standard normal distribution
    ci_lower = mean - z * (std / np.sqrt(T))
    ci_upper = mean + z * (std / np.sqrt(T))

    # 95% PI for individual outcomes — percentile-based across paths
    # 95% Prediction Interval
    pi_lower = np.percentile(paths, 2.5, axis=0)
    pi_upper = np.percentile(paths, 97.5, axis=0)

    return pd.DataFrame({
        "Date": future_dates,
        "Mean": mean,
        "CI_Lower": ci_lower, "CI_Upper": ci_upper,
        "PI_Lower": pi_lower, "PI_Upper": pi_upper
    })

# %%
# ------- Widgets & Plot --------
days_slider = widgets.IntSlider(value=7, min=1, max=30, step=1, description="Days:")
# Prediction the possible futures between 100 and 300
T_slider    = widgets.IntSlider(value=100, min=20, max=150, step=20, description="MC runs:")
conf_dd     = widgets.Dropdown(
    options=[("80%",0.80),("90%",0.90),("95%",0.95),("99%",0.99)],
    value=0.95, description="Confidence:"
)
output_box  = widgets.Output()

# %% [markdown]
# ## Plot with CI and PI

# %%
def plot_open_mc(n_days: int, T: int, conf: float):
    with output_box:
        output_box.clear_output(wait=True)
        fut = forecast_open_mc_dropout(n_days=n_days, T=T, conf=conf)

        # --- PLOT ---
        fig = go.Figure()
        # history
        fig.add_trace(go.Scatter(x=data_train["Date"], y=data_train["Open"],
                                 name="History (Open)", mode="lines"))
        # mean line
        fig.add_trace(go.Scatter(x=fut["Date"], y=fut["Mean"],
                                 name=f"Mean forecast (+{n_days}d)", mode="lines+markers"))

        # CI band (mean uncertainty) – usually narrow
        fig.add_trace(go.Scatter(
            x=fut["Date"], y=fut["CI_Upper"],
            mode="lines", line=dict(width=0),  # invisible line
            showlegend=False
        ))
        fig.add_trace(go.Scatter(
            x=fut["Date"], y=fut["CI_Lower"],
            name=f"{int(conf*100)}% CI (mean)",
            mode="lines", line=dict(width=0),
            fill="tonexty", fillcolor="rgba(200,100,255,0.3)"  # purple shade
        ))

        # PI band (actuals uncertainty) – wider
        fig.add_trace(go.Scatter(
            x=fut["Date"], y=fut["PI_Upper"],
            mode="lines", line=dict(width=0),
            showlegend=False
        ))
        fig.add_trace(go.Scatter(
            x=fut["Date"], y=fut["PI_Lower"],
            name=f"{int(conf*100)}% PI (actual)",
            mode="lines", line=dict(width=0),
            fill="tonexty", fillcolor="rgba(100,200,255,0.3)"  # blue shade
        ))

        # Forecast boundary (robust datetime method)
        cutoff_dt = pd.to_datetime(data_train["Date"].max()).to_pydatetime()
        fig.add_shape(type="line", x0=cutoff_dt, x1=cutoff_dt, y0=0, y1=1,
                      xref="x", yref="paper", line=dict(dash="dot"))
        fig.add_annotation(x=cutoff_dt, y=1, xref="x", yref="paper",
                           text="Forecast start", showarrow=False, yshift=10)

        fig.update_layout(
            title=f"Open forecast with CI & PI (MC Dropout, T={T}, {int(conf*100)}%)",
            xaxis_title="Date", yaxis_title="Open Price",
            legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
            margin=dict(l=0, r=0, t=60, b=0),
        )
        fig.update_xaxes(type="date")
        fig.show()

ui = widgets.VBox([days_slider, T_slider, conf_dd])
out = widgets.interactive_output(plot_open_mc, {"n_days": days_slider, "T": T_slider, "conf": conf_dd})

display(ui, output_box)
# Out:
# VBox(children=(IntSlider(value=7, description='Days:', max=30, min=1), IntSlider(value=100, description='MC ru…
# Output()
